# %%
import pandas as pd
from pandas import DataFrame
import csv
import numpy as np
from math import sin, cos, sqrt, atan2, radians
import datetime
# %matplotlib inline
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
from statsmodels.sandbox.regression.predstd import wls_prediction_std
from statsmodels.iolib.table import (SimpleTable, default_txt_fmt)
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_rows', 40)

# %%
i = 1992
while i < 2020:
    file = 'Gravity-%s.csv' %  i
    df = pd.read_csv(file, delimiter=',')
    

    #df=df.loc[(df['iso3num_o'] == 24) | (df['iso3num_o'] == 532) | (df['iso3num_o'] == 32) | (df['iso3num_o'] == 36) | (df['iso3num_o'] == 40) | (df['iso3num_o'] == 100) | (df['iso3num_o'] == 68) | (df['iso3num_o'] == 76) | (df['iso3num_o'] == 124) | (df['iso3num_o'] == 756) | (df['iso3num_o'] == 152) | (df['iso3num_o'] == 156) | (df['iso3num_o'] == 120) | (df['iso3num_o'] == 180) | (df['iso3num_o'] == 170) | (df['iso3num_o'] == 188) | (df['iso3num_o'] == 200) | (df['iso3num_o'] == 192) | (df['iso3num_o'] == 196) | (df['iso3num_o'] == 280) | (df['iso3num_o'] == 262) | (df['iso3num_o'] == 208) | (df['iso3num_o'] == 214) | (df['iso3num_o'] == 12) | (df['iso3num_o'] == 218) | (df['iso3num_o'] == 818) | (df['iso3num_o'] == 724) | (df['iso3num_o'] == 230) | (df['iso3num_o'] == 246) | (df['iso3num_o'] == 250) | (df['iso3num_o'] == 826) | (df['iso3num_o'] == 288) | (df['iso3num_o'] == 300) | (df['iso3num_o'] == 320) | (df['iso3num_o'] == 344) | (df['iso3num_o'] == 340) | (df['iso3num_o'] == 332) | (df['iso3num_o'] == 348) | (df['iso3num_o'] == 360) | (df['iso3num_o'] == 356) | (df['iso3num_o'] == 372) | (df['iso3num_o'] == 364) | (df['iso3num_o'] == 368) | (df['iso3num_o'] == 352) | (df['iso3num_o'] == 376) | (df['iso3num_o'] == 380) | (df['iso3num_o'] == 388) | (df['iso3num_o'] == 392) | (df['iso3num_o'] == 404) | (df['iso3num_o'] == 410) | (df['iso3num_o'] == 144) | (df['iso3num_o'] == 504) | (df['iso3num_o'] == 450) | (df['iso3num_o'] == 484) | (df['iso3num_o'] == 104) | (df['iso3num_o'] == 508) | (df['iso3num_o'] == 566) | (df['iso3num_o'] == 558) | (df['iso3num_o'] == 528) | (df['iso3num_o'] == 578) | (df['iso3num_o'] == 554) | (df['iso3num_o'] == 586) | (df['iso3num_o'] == 590) | (df['iso3num_o'] == 604) | (df['iso3num_o'] == 608) | (df['iso3num_o'] == 616) | (df['iso3num_o'] == 620) | (df['iso3num_o'] == 600) | (df['iso3num_o'] == 258) | (df['iso3num_o'] == 642) | (df['iso3num_o'] == 682) | (df['iso3num_o'] == 736) | (df['iso3num_o'] == 222) | (df['iso3num_o'] == 810) | (df['iso3num_o'] == 740) | (df['iso3num_o'] == 752) | (df['iso3num_o'] == 760) | (df['iso3num_o'] == 764) | (df['iso3num_o'] == 780) | (df['iso3num_o'] == 788) | (df['iso3num_o'] == 792) | (df['iso3num_o'] == 834) | (df['iso3num_o'] == 800) | (df['iso3num_o'] == 858) | (df['iso3num_o'] == 840) | (df['iso3num_o'] == 862) | (df['iso3num_o'] == 890) | (df['iso3num_o'] == 710) | (df['iso3num_o'] == 894) | (df['iso3num_o'] == 716) | (df['iso3num_o'] == 203) | (df['iso3num_o'] == 276) | (df['iso3num_o'] == 643) | (df['iso3num_o'] == 703)]    
    #df=df.loc[(df['iso3num_d'] == 24) | (df['iso3num_d'] == 532) | (df['iso3num_d'] == 32) | (df['iso3num_d'] == 36) | (df['iso3num_d'] == 40) | (df['iso3num_d'] == 100) | (df['iso3num_d'] == 68) | (df['iso3num_d'] == 76) | (df['iso3num_d'] == 124) | (df['iso3num_d'] == 756) | (df['iso3num_d'] == 152) | (df['iso3num_d'] == 156) | (df['iso3num_d'] == 120) | (df['iso3num_d'] == 180) | (df['iso3num_d'] == 170) | (df['iso3num_d'] == 188) | (df['iso3num_d'] == 200) | (df['iso3num_d'] == 192) | (df['iso3num_d'] == 196) | (df['iso3num_d'] == 280) | (df['iso3num_d'] == 262) | (df['iso3num_d'] == 208) | (df['iso3num_d'] == 214) | (df['iso3num_d'] == 12) | (df['iso3num_d'] == 218) | (df['iso3num_d'] == 818) | (df['iso3num_d'] == 724) | (df['iso3num_d'] == 230) | (df['iso3num_d'] == 246) | (df['iso3num_d'] == 250) | (df['iso3num_d'] == 826) | (df['iso3num_d'] == 288) | (df['iso3num_d'] == 300) | (df['iso3num_d'] == 320) | (df['iso3num_d'] == 344) | (df['iso3num_d'] == 340) | (df['iso3num_d'] == 332) | (df['iso3num_d'] == 348) | (df['iso3num_d'] == 360) | (df['iso3num_d'] == 356) | (df['iso3num_d'] == 372) | (df['iso3num_d'] == 364) | (df['iso3num_d'] == 368) | (df['iso3num_d'] == 352) | (df['iso3num_d'] == 376) | (df['iso3num_d'] == 380) | (df['iso3num_d'] == 388) | (df['iso3num_d'] == 392) | (df['iso3num_d'] == 404) | (df['iso3num_d'] == 410) | (df['iso3num_d'] == 144) | (df['iso3num_d'] == 504) | (df['iso3num_d'] == 450) | (df['iso3num_d'] == 484) | (df['iso3num_d'] == 104) | (df['iso3num_d'] == 508) | (df['iso3num_d'] == 566) | (df['iso3num_d'] == 558) | (df['iso3num_d'] == 528) | (df['iso3num_d'] == 578) | (df['iso3num_d'] == 554) | (df['iso3num_d'] == 586) | (df['iso3num_d'] == 590) | (df['iso3num_d'] == 604) | (df['iso3num_d'] == 608) | (df['iso3num_d'] == 616) | (df['iso3num_d'] == 620) | (df['iso3num_d'] == 600) | (df['iso3num_d'] == 258) | (df['iso3num_d'] == 642) | (df['iso3num_d'] == 682) | (df['iso3num_d'] == 736) | (df['iso3num_d'] == 222) | (df['iso3num_d'] == 810) | (df['iso3num_d'] == 740) | (df['iso3num_d'] == 752) | (df['iso3num_d'] == 760) | (df['iso3num_d'] == 764) | (df['iso3num_d'] == 780) | (df['iso3num_d'] == 788) | (df['iso3num_d'] == 792) | (df['iso3num_d'] == 834) | (df['iso3num_d'] == 800) | (df['iso3num_d'] == 858) | (df['iso3num_d'] == 840) | (df['iso3num_d'] == 862) | (df['iso3num_d'] == 890) | (df['iso3num_d'] == 710) | (df['iso3num_d'] == 894) | (df['iso3num_d'] == 716) | (df['iso3num_d'] == 203) | (df['iso3num_d'] == 276) | (df['iso3num_d'] == 643) | (df['iso3num_d'] == 703)]
    
    df=df.loc[df['geoscheme_o'] == 143]

    print(i)
    i+=1
    
    df['tradeflow_mean'] = df[['tradeflow_comtrade_o','tradeflow_comtrade_d','tradeflow_imf_o','tradeflow_imf_d']].mean(axis=1)
    df['const'] = 1
    df['l_tradeflow_mean'] = np.log(df['tradeflow_mean'])
    df['l_distw'] = np.log(df['distw'])
    df['l_gdp_o'] = np.log(df['gdp_o'])
    df['l_gdp_d'] = np.log(df['gdp_d'])
    df['l_pop_o'] = np.log(df['pop_o'])
    df['l_pop_d'] = np.log(df['pop_d'])
    df['gatt_joint'] = df['gatt_o'] * df['gatt_d']
    df['wto_joint'] = df['wto_o'] * df['wto_d']
    df['eu_joint'] = df['eu_o'] * df['eu_d']
    

    if i < 1957:
        reg = sm.OLS(endog=df['l_tradeflow_mean'], exog=df[['const','l_distw','l_gdp_o','l_gdp_d','l_pop_o','l_pop_d','contig','comlang_off','comlang_ethno','comcol','col45','comrelig','gatt_joint','rugged_popw_o','rugged_popw_d','desert_o','desert_d','tropical_o','tropical_d','island_o','island_d','landlocked_o','landlocked_d']], \
        missing='drop')
    elif i < 1995:
        reg = sm.OLS(endog=df['l_tradeflow_mean'], exog=df[['const','l_distw','l_gdp_o','l_gdp_d','l_pop_o','l_pop_d','contig','comlang_off','comlang_ethno','comcol','col45','comrelig','gatt_joint','rugged_popw_o','rugged_popw_d','desert_o','desert_d','tropical_o','tropical_d','island_o','island_d','landlocked_o','landlocked_d']], \
        missing='drop')
    else:
        reg = sm.OLS(endog=df['l_tradeflow_mean'], exog=df[['const','l_distw','l_gdp_o','l_gdp_d','l_pop_o','l_pop_d','contig','comlang_off','comlang_ethno','comcol','col45','comrelig','wto_joint','rugged_popw_o','rugged_popw_d','desert_o','desert_d','tropical_o','tropical_d','island_o','island_d','landlocked_o','landlocked_d']], \
        missing='drop')
    
    results = reg.fit()
    type(results)
    print(results.summary())
# Out:
# 1992
#                             OLS Regression Results
# ...
# Dep. Variable:       l_tradeflow_mean   R-squared:                       0.511
# Model:                            OLS   Adj. R-squared:                  0.450
# Method:                 Least Squares   F-statistic:                     8.423
# Date:                Sun, 20 Jun 2021   Prob (F-statistic):           4.62e-15
# Time:                        17:48:16   Log-Likelihood:                -334.96
# No. Observations:                 164   AIC:                             707.9
# Df Residuals:                     145   BIC:                             766.8
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            44.4588     83.836      0.530      0.597    -121.240     210.157
# ...
